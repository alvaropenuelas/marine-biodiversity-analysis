# %%
import requests
import pandas as pd
import os

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
os.makedirs("../data", exist_ok=True)
print("Data folder ready")
# Out:
# Data folder ready

# %%
url = "https://api.obis.org/v3/occurrence"
params = {
    "scientificname": "Orcinus orca",
    "size": 5000
}

print("Downloading Orcinus orca occurrences from OBIS...")
response = requests.get(url, params=params)
data = response.json()

df = pd.DataFrame(data["results"])
print(f"Downloaded {len(df)} records")
print(f"Columns available: {list(df.columns)}")
# Out:
# ...
# Downloaded 5000 records
# ...

# %%
df.to_csv("../data/orcinus_orca_obis.csv", index=False)
print("Dataset saved to /data/orcinus_orca_obis.csv")
# Out:
# Dataset saved to /data/orcinus_orca_obis.csv
